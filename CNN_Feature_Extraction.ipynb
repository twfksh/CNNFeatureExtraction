# %%
from datasets import load_dataset

# loading CIFAR10 image dataset from HuggingFace
train_dataset = load_dataset('cifar10', split='train')
test_dataset = load_dataset('cifar10', split='test')

num_classes = len(set(train_dataset['label'])) # get number of labels in dataset

# %%
import torchvision.transforms as transforms

# resize all images to a fixed size 32 and normalize using suitable mean and standard deviation for the dataset
img_size = 32
mean = [0.4670, 0.4735, 0.4662]
std = [0.2496, 0.2489, 0.2521]
preprocess = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=mean, std=std)
])

from tqdm.auto import tqdm

train_inputs = []

def preprocess_dataset(dataset):
    inputs = []
    for record in tqdm(dataset):
        image, label = record['img'], record['label']
        if image.mode == 'L':
            image = image.convert('RGB')
        input_tensor = preprocess(image)
        inputs.append([input_tensor, label])
    return inputs

# preprocess training and test dataset
train_inputs = preprocess_dataset(train_dataset)
test_inputs = preprocess_dataset(test_dataset)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
from torch.utils.data import DataLoader

batch_size = 128

dataloader_train = DataLoader(train_inputs, batch_size=batch_size, shuffle=True)
dataloader_test = DataLoader(test_inputs, batch_size=batch_size, shuffle=False)

# %%
import torch.nn as nn

# constructing ConvNet
class ConvNet(nn.Module):
    def __init__(self, num_classes):
        super(ConvNet, self).__init__()

        self.conv_layer1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.conv_layer2 = nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.conv_layer3 = nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()

        self.conv_layer4 = nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()

        self.conv_layer5 = nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.pool5 = nn.MaxPool2d(kernel_size=3, stride=2)

        self.dropout6 = nn.Dropout(p=0.5)
        self.fc6 = nn.Linear(in_features=2304, out_features=512)
        self.relu6 = nn.ReLU()

        self.dropout7 = nn.Dropout(p=0.5)
        self.fc7 = nn.Linear(in_features=512, out_features=256)
        self.relu7 = nn.ReLU()

        self.fc8 = nn.Linear(in_features=256, out_features=num_classes)

    def forward(self, x):
        x = self.conv_layer1(x)
        x = self.relu1(x)
        x = self.pool1(x)

        x = self.conv_layer2(x)
        x = self.relu2(x)
        x = self.pool2(x)

        x = self.conv_layer3(x)
        x = self.relu3(x)

        x = self.conv_layer4(x)
        x = self.relu4(x)

        x = self.conv_layer5(x)
        x = self.relu5(x)
        x = self.pool5(x)

        x = x.reshape(x.size(0), -1)

        x = self.dropout6(x)
        x = self.fc6(x)
        x = self.relu6(x)

        x = self.dropout7(x)
        x = self.fc7(x)
        x = self.relu7(x)

        x = self.fc8(x)

        return x

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = ConvNet(num_classes=num_classes).to(device)

loss_func = nn.CrossEntropyLoss()
learning_rate = 0.008
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    for i, (images, labels) in enumerate(dataloader_train):
        # move tensors to configured device
        images, labels = images.to(device), labels.to(device)

        # forward propagation
        outputs = model(images)
        loss = loss_func(outputs, labels)

        # backward propagation and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # check validation loss and acc of each epoch
    with torch.no_grad():
        # switch model to eval (not train) model
        model.eval()
        total, correct = 0, 0
        all_test_loss = []
        for images, labels in dataloader_test:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            total += labels.size(0)
            # calc predictions
            predicted = torch.argmax(outputs, dim=1)
            # calc actual values
            correct += (predicted == labels).sum().item()
            # calc the loss
            all_test_loss.append(loss_func(outputs, labels).item())

        # calc test-loss
        mean_test_loss = sum(all_test_loss) / len(all_test_loss)
        # calc test-accuracy
        mean_test_acc = 100 * (correct / total)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Test-Loss: {mean_test_loss:.4f}, Test-Accuracy: {mean_test_acc:.1f}%')

# save to file
torch.save(model, 'cnn.pt')
# Out:
# Epoch [1/100], Loss: 2.3052, Test-Loss: 2.3024, Test-Accuracy: 11.5%
# Epoch [2/100], Loss: 2.3021, Test-Loss: 2.3014, Test-Accuracy: 15.0%
# Epoch [3/100], Loss: 2.3021, Test-Loss: 2.3000, Test-Accuracy: 12.7%
# Epoch [4/100], Loss: 2.2980, Test-Loss: 2.2966, Test-Accuracy: 15.9%
# Epoch [5/100], Loss: 2.2784, Test-Loss: 2.2809, Test-Accuracy: 19.7%
# Epoch [6/100], Loss: 2.1417, Test-Loss: 2.0701, Test-Accuracy: 21.1%
# Epoch [7/100], Loss: 1.9233, Test-Loss: 1.9582, Test-Accuracy: 24.4%
# Epoch [8/100], Loss: 1.9183, Test-Loss: 1.9837, Test-Accuracy: 24.9%
# Epoch [9/100], Loss: 1.8472, Test-Loss: 1.9937, Test-Accuracy: 24.9%
# Epoch [10/100], Loss: 1.8956, Test-Loss: 1.7262, Test-Accuracy: 34.0%
# Epoch [11/100], Loss: 1.7636, Test-Loss: 1.6831, Test-Accuracy: 35.9%
# Epoch [12/100], Loss: 1.6355, Test-Loss: 1.6761, Test-Accuracy: 36.1%
# Epoch [13/100], Loss: 1.6145, Test-Loss: 1.5939, Test-Accuracy: 38.6%
# Epoch [14/100], Loss: 1.6925, Test-Loss: 1.5753, Test-Accuracy: 40.8%
# Epoch [15/100], Loss: 1.4327, Test-Loss: 1.5060, Test-Accuracy: 42.3%
# Epoch [16/100], Loss: 1.6621, Test-Loss: 1.4685, Test-Accuracy: 44.4%
# Epoch [17/100], Loss: 1.4429, Test-Loss: 1.4528, Test-Accuracy: 45.5%
# Epoch [18/100], Loss: 1.5242, Test-Loss: 1.4219, Test-Accuracy: 47.1%
# Epoch [19/100], Loss: 1.3232, Test-Loss: 1.4096, Test-Accuracy: 47.6%
# Epoch [20/100], Loss: 1.4767, Test-Loss: 1.3449, Test-Accuracy: 50.0%
# Epoch [21/100], Loss: 1.0877, Test-Loss: 1.3426, Test-Accuracy: 50.1%
# Epoch [22/100], Loss: 1.2429, Test-Loss: 1.2687, Test-Accuracy: 53.2%
# Epoch [23/100], Loss: 1.3597, Test-Loss: 1.2451, Test-Accuracy: 54.5%
# Epoch [24/100], Loss: 1.3793, Test-Loss: 1.2877, Test-Accuracy: 53.0%
# Epoch [25/100], Loss: 1.3282, Test-Loss: 1.2552, Test-Accuracy: 54.0%
# Epoch [26/100], Loss: 1.3851, Test-Loss: 1.2147, Test-Accuracy: 55.6%
# Epoch [27/100], Loss: 1.1716, Test-Loss: 1.1204, Test-Accuracy: 59.7%
# Epoch [28/100], Loss: 1.0176, Test-Loss: 1.0883, Test-Accuracy: 61.8%
# Epoch [29/100], Loss: 1.3096, Test-Loss: 1.1087, Test-Accuracy: 59.5%
# Epoch [30/100], Loss: 1.0407, Test-Loss: 1.0741, Test-Accuracy: 62.0%
# Epoch [31/100], Loss: 0.9716, Test-Loss: 1.0319, Test-Accuracy: 63.7%
# Epoch [32/100], Loss: 1.3023, Test-Loss: 0.9825, Test-Accuracy: 65.3%
# Epoch [33/100], Loss: 1.1137, Test-Loss: 0.9926, Test-Accuracy: 64.8%
# Epoch [34/100], Loss: 0.9485, Test-Loss: 0.9957, Test-Accuracy: 64.3%
# Epoch [35/100], Loss: 1.1083, Test-Loss: 0.9643, Test-Accuracy: 65.6%
# Epoch [36/100], Loss: 0.8798, Test-Loss: 0.9037, Test-Accuracy: 67.7%
# Epoch [37/100], Loss: 1.0666, Test-Loss: 0.9370, Test-Accuracy: 67.2%
# Epoch [38/100], Loss: 0.9089, Test-Loss: 0.8610, Test-Accuracy: 70.0%
# Epoch [39/100], Loss: 0.8154, Test-Loss: 0.8627, Test-Accuracy: 69.4%
# Epoch [40/100], Loss: 0.9882, Test-Loss: 0.8704, Test-Accuracy: 69.4%
# Epoch [41/100], Loss: 0.8312, Test-Loss: 0.8746, Test-Accuracy: 69.4%
# Epoch [42/100], Loss: 0.8712, Test-Loss: 0.9165, Test-Accuracy: 67.7%
# Epoch [43/100], Loss: 0.7282, Test-Loss: 0.8886, Test-Accuracy: 68.9%
# Epoch [44/100], Loss: 0.6748, Test-Loss: 0.7823, Test-Accuracy: 72.7%
# Epoch [45/100], Loss: 0.8291, Test-Loss: 0.7774, Test-Accuracy: 72.9%
# Epoch [46/100], Loss: 0.7854, Test-Loss: 0.7447, Test-Accuracy: 74.2%
# Epoch [47/100], Loss: 0.7065, Test-Loss: 0.7739, Test-Accuracy: 73.1%
# Epoch [48/100], Loss: 0.5664, Test-Loss: 0.7518, Test-Accuracy: 73.6%
# Epoch [49/100], Loss: 0.7032, Test-Loss: 0.7210, Test-Accuracy: 74.7%
# Epoch [50/100], Loss: 0.4613, Test-Loss: 0.7410, Test-Accuracy: 74.3%
# Epoch [51/100], Loss: 0.6369, Test-Loss: 0.7780, Test-Accuracy: 72.8%
# Epoch [52/100], Loss: 0.5798, Test-Loss: 0.7080, Test-Accuracy: 75.4%
# Epoch [53/100], Loss: 0.7934, Test-Loss: 0.7324, Test-Accuracy: 75.1%
# Epoch [54/100], Loss: 0.7759, Test-Loss: 0.7596, Test-Accuracy: 73.8%
# Epoch [55/100], Loss: 0.5073, Test-Loss: 0.7223, Test-Accuracy: 75.5%
# Epoch [56/100], Loss: 0.7092, Test-Loss: 0.8292, Test-Accuracy: 72.5%
# Epoch [57/100], Loss: 0.6428, Test-Loss: 0.6562, Test-Accuracy: 78.0%
# Epoch [58/100], Loss: 0.7390, Test-Loss: 0.6728, Test-Accuracy: 77.4%
# Epoch [59/100], Loss: 0.5750, Test-Loss: 0.7189, Test-Accuracy: 75.7%
# Epoch [60/100], Loss: 0.5194, Test-Loss: 0.6824, Test-Accuracy: 77.1%
# Epoch [61/100], Loss: 0.4377, Test-Loss: 0.6501, Test-Accuracy: 78.3%
# Epoch [62/100], Loss: 0.5613, Test-Loss: 0.6908, Test-Accuracy: 76.8%
# Epoch [63/100], Loss: 0.5274, Test-Loss: 0.6983, Test-Accuracy: 77.4%
# Epoch [64/100], Loss: 0.4685, Test-Loss: 0.6759, Test-Accuracy: 77.3%
# Epoch [65/100], Loss: 0.4427, Test-Loss: 0.6177, Test-Accuracy: 79.3%
# Epoch [66/100], Loss: 0.4684, Test-Loss: 0.6346, Test-Accuracy: 79.0%
# Epoch [67/100], Loss: 0.4418, Test-Loss: 0.5981, Test-Accuracy: 80.3%
# Epoch [68/100], Loss: 0.3111, Test-Loss: 0.6866, Test-Accuracy: 77.9%
# Epoch [69/100], Loss: 0.3890, Test-Loss: 0.5933, Test-Accuracy: 80.7%
# Epoch [70/100], Loss: 0.3520, Test-Loss: 0.6325, Test-Accuracy: 79.0%
# Epoch [71/100], Loss: 0.2677, Test-Loss: 0.6513, Test-Accuracy: 78.5%
# Epoch [72/100], Loss: 0.4092, Test-Loss: 0.7164, Test-Accuracy: 76.7%
# Epoch [73/100], Loss: 0.3923, Test-Loss: 0.6536, Test-Accuracy: 79.4%
# Epoch [74/100], Loss: 0.4983, Test-Loss: 0.6093, Test-Accuracy: 80.4%
# Epoch [75/100], Loss: 0.2872, Test-Loss: 0.6237, Test-Accuracy: 80.6%
# Epoch [76/100], Loss: 0.4297, Test-Loss: 0.5979, Test-Accuracy: 80.8%
# Epoch [77/100], Loss: 0.4921, Test-Loss: 0.7942, Test-Accuracy: 75.8%
# Epoch [78/100], Loss: 0.2376, Test-Loss: 0.6646, Test-Accuracy: 78.8%
# Epoch [79/100], Loss: 0.3964, Test-Loss: 0.6834, Test-Accuracy: 79.8%
# Epoch [80/100], Loss: 0.3737, Test-Loss: 0.6451, Test-Accuracy: 79.6%
# Epoch [81/100], Loss: 0.2208, Test-Loss: 0.6376, Test-Accuracy: 80.7%
# Epoch [82/100], Loss: 0.2092, Test-Loss: 0.6283, Test-Accuracy: 81.6%
# Epoch [83/100], Loss: 0.2227, Test-Loss: 0.6650, Test-Accuracy: 80.1%
# Epoch [84/100], Loss: 0.2291, Test-Loss: 0.6265, Test-Accuracy: 81.3%
# Epoch [85/100], Loss: 0.1444, Test-Loss: 0.6736, Test-Accuracy: 81.0%
# Epoch [86/100], Loss: 0.3961, Test-Loss: 0.6552, Test-Accuracy: 80.5%
# Epoch [87/100], Loss: 0.3131, Test-Loss: 0.8924, Test-Accuracy: 76.3%
# Epoch [88/100], Loss: 0.3364, Test-Loss: 0.7281, Test-Accuracy: 78.9%
# Epoch [89/100], Loss: 0.1244, Test-Loss: 0.6665, Test-Accuracy: 81.3%
# Epoch [90/100], Loss: 0.1893, Test-Loss: 0.7589, Test-Accuracy: 79.5%
# Epoch [91/100], Loss: 0.1182, Test-Loss: 0.7102, Test-Accuracy: 81.4%
# Epoch [92/100], Loss: 0.1185, Test-Loss: 0.6675, Test-Accuracy: 81.7%
# Epoch [93/100], Loss: 0.1063, Test-Loss: 0.8143, Test-Accuracy: 78.7%
# Epoch [94/100], Loss: 0.2594, Test-Loss: 0.7269, Test-Accuracy: 80.7%
# Epoch [95/100], Loss: 0.1403, Test-Loss: 0.8539, Test-Accuracy: 79.0%
# Epoch [96/100], Loss: 0.0924, Test-Loss: 0.7007, Test-Accuracy: 81.7%
# Epoch [97/100], Loss: 0.1391, Test-Loss: 0.8165, Test-Accuracy: 80.1%
# Epoch [98/100], Loss: 0.1190, Test-Loss: 0.7086, Test-Accuracy: 81.6%
# Epoch [99/100], Loss: 0.1444, Test-Loss: 0.8003, Test-Accuracy: 80.7%
# Epoch [100/100], Loss: 0.1215, Test-Loss: 0.9059, Test-Accuracy: 80.3%
